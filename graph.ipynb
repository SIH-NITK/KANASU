# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import glob

# %%
filenames1 = [img for img in glob.glob("C:\\Users\\naray\\Downloads\\Newfolder2\\*.jpg")]

images = []
for img in filenames1:
    n= cv2.imread(img)
    images.append(n)
    
filenames2 = [img for img in glob.glob("C:\\Users\\naray\\Downloads\\Newfolder\\*.jpg")]

images2 = []
for img in filenames2:
    n= cv2.imread(img)
    images2.append(n)
    
images3 = []

# %%
arr=[]
arr2=[]
for image in images:
    arr+=[np.average(np.asarray(image))]

    
for image in images2:
    arr2+=[np.average(np.asarray(image))]
    
arr3=(np.asarray(arr) - np.asarray(arr2))/(np.asarray(arr)+np.asarray(arr2))

# %%
plt.plot(arr)

# %%
plt.plot(arr2)

# %%
plt.plot(arr3)
